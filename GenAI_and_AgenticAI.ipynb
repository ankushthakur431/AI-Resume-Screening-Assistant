# %%
# Setup the workspace path so the notebook can import the companion modules.
import sys
from pathlib import Path
import notebook_setup

print("Notebook environment ready")
# Out:
# Notebook environment ready

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Dell\anaconda3\python.exe

# %%
# !pip install -U langchain langchain-core langchain-community langchain-text-splitters langgraph faiss-cpu pypdf streamlit openai python-dotenv

# %%
# !pip install reportlab

# %%
import sys
print(sys.executable)

# !python -m pip show reportlab
# Out:
# C:\Users\Dell\anaconda3\python.exe
# Name: reportlab
# Version: 5.0.0
# Summary: The Reportlab Toolkit
# Home-page: https://www.reportlab.com/
# Author: Andy Robinson, Robin Becker, the ReportLab team and the community
# Author-email: reportlab-users@lists2.reportlab.com
# License: BSD license (see license.txt for details), Copyright (c) 2000-2025, ReportLab Inc.
# Location: C:\Users\Dell\anaconda3\Lib\site-packages
# Requires: charset-normalizer, pillow
# Required-by:

# %%
# !python -m pip install reportlab

# %%
from reportlab.pdfgen import canvas
print("ReportLab imported successfully!")
# Out:
# ReportLab imported successfully!

# %%
from agentic_app import run_demo
from pathlib import Path
import json

base_dir = Path.cwd()

result = run_demo(base_dir)
print(json.dumps(result, indent=2))
# Out:
# {
#   "resume_results": [
#     {
#       "match_score": 87,
#       "strengths": [
#         "python",
#         "sql",
#         "machine learning"
#       ],
#       "weaknesses": [
#         "Limited evidence of production deployment"
#       ],
#       "missing_skills": [
#         "cloud deployment",
#         "Spark"
#       ],
#       "recommendation": "Proceed with interview",
#       "evidence": [
#         "Resume contains experience aligned to the stated role"
#       ],
#       "resume_name": "resume_alice.pdf"
#     },
#     {
#       "match_score": 95,
#       "strengths": [
#         "python",
#         "machine learning",
#         "deep learning"
#       ],
#       "weaknesses": [
#         "Limited evidence of production deployment"
#       ],
#       "missing_skills": [
#         "cloud deployment",
#         "Spark",
#         "SQL"
#       ],
#       "recommendation": "Proceed with interview",
#       "evidence": [
# ...

# %%
result = run_demo(base_dir)

# %%
from agentic_app import demo_claim_examples, evaluate_resumes, process_claim, create_sample_resume_pdfs, run_demo
from pathlib import Path
import json

base_dir = Path.cwd()
result = run_demo(base_dir)
print(json.dumps(result, indent=2))
# Out:
# {
#   "resume_results": [
#     {
#       "match_score": 87,
#       "strengths": [
#         "python",
#         "sql",
#         "machine learning"
#       ],
#       "weaknesses": [
#         "Limited evidence of production deployment"
#       ],
#       "missing_skills": [
#         "cloud deployment",
#         "Spark"
#       ],
#       "recommendation": "Proceed with interview",
#       "evidence": [
#         "Resume contains experience aligned to the stated role"
#       ],
#       "resume_name": "resume_alice.pdf"
#     },
#     {
#       "match_score": 95,
#       "strengths": [
#         "python",
#         "machine learning",
#         "deep learning"
#       ],
#       "weaknesses": [
#         "Limited evidence of production deployment"
#       ],
#       "missing_skills": [
#         "cloud deployment",
#         "Spark",
#         "SQL"
#       ],
#       "recommendation": "Proceed with interview",
#       "evidence": [
# ...
